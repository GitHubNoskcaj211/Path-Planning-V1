# %%
from tree import Tree
from occupancygrid import OccupancyGrid
from Simulation import Simulation
import matplotlib.pyplot as plt
import numpy as np
import time
from robot import Robot

# %%
start = (0,0,0)
# xmin, ymin, xmax, ymax
world_bounds = (0,0,30,30)
robot = Robot(start)
occupancy = OccupancyGrid(world_bounds, robot.sensing_radius, robot.sensing_angle)
rrtree = Tree((robot.position.x, robot.position.y), 3, world_bounds, occupancy)

rrtree.build_tree(1000)

fig, ax = plt.subplots()
fig.set_figwidth(8)
fig.set_figheight(8)

rrtree.display(ax)

fig.show()
# Out:
# /Users/aoqu/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   app.launch_new_instance()

# %%
start = (0,0,0)
goal = (10,10)
# xmin, ymin, xmax, ymax
world_bounds = (0,0,10,10)
sim = Simulation(start, goal, world_bounds)
sim.build_initial_rrt()
for i in sim.path:
    print(i)
sim.display()

while not sim.step():
    sim.display()
    
sim.display()

input()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-1787d73b8e8f> in <module>
#       4 world_bounds = (0,0,10,10)
#       5 sim = Simulation(start, goal, world_bounds)
# ----> 6 sim.build_initial_rrt()
#       7 for i in sim.path:
#       8     print(i)
#
# ~/Desktop/Robotics/Path-Planning-V1/Simulation.py in build_initial_rrt(self)
#      70     def build_initial_rrt(self):
#      71         # while we cannot add the goal node
# ---> 72         while not self.rrtree.add_goal_node(self.goal.x, self.goal.y):
#      73             self.rrtree.build_tree(750)
#      74
#
# ~/Desktop/Robotics/Path-Planning-V1/tree.py in add_goal_node(self, goal_x, goal_y)
#     102     def add_goal_node(self, goal_x, goal_y):
#     103         goal_node = Node(Point(goal_x, goal_y))
# --> 104         if self.add_node_to_tree(goal_node):
#     105             self.goal_node = goal_node
#     106             return True
#
# ~/Desktop/Robotics/Path-Planning-V1/tree.py in add_node_to_tree(self, new_node)
#     120     def add_node_to_tree(self, new_node):
#     121         # get the nearest nodes that are not blocked by an obstacle to the new_node
# --> 122         nearest_nodes = self.get_nearest_nodes(new_node)
#     123
#     124         if len(nearest_nodes) == 0:
#
# ~/Desktop/Robotics/Path-Planning-V1/tree.py in get_nearest_nodes(self, node)
#     185         for n in self.nodes:
#     186             if shortest_distance == None or node.distance(n) <= self.radius or node.distance(n) < shortest_distance:
# --> 187                 if self.clear_path(n, node): # move this check up
#     188                     node_distance_list.append([n.index, n.distance(node)])
#     189                     shortest_distance = node.distance(n)
#
# ~/Desktop/Robotics/Path-Planning-V1/tree.py in clear_path(self, node1, node2)
#     215             return True
#     216
# --> 217         return self.occupancy_grid.query_free(node1.pos.x, node1.pos.y, node2.pos.x, node2.pos.y)
#     218
#     219     def clear_tree(self):
#
# ~/Desktop/Robotics/Path-Planning-V1/occupancygrid.py in query_free(self, x1, y1, x2, y2)
#      80                 y_list = [y-1 for y in y_list]
#      81             for y in y_list:
# ---> 82                 if self.grid[x_left, y, 0]:
#      83                     return False
#      84         return True
#
# IndexError: index 10 is out of bounds for axis 1 with size 10
